# %% [markdown]
# <a href="https://colab.research.google.com/github/NAGADEEP92/AI-ML-DS/blob/main/Demo_ColPali_Vision_based_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook is based on these notebooks:
#
#
# https://github.com/AnswerDotAI/byaldi/blob/main/examples/chat_with_your_pdf.ipynb
#
#
# https://github.com/merveenoyan/smol-vision/blob/main/ColPali_%2B_Qwen2_VL.ipynb

# %% [markdown]
# ## Setup

# %%
# !pip install byaldi claudette
# !sudo apt-get install -y poppler-utils
# !pip install openai
# Out:
# Collecting byaldi
#   Downloading Byaldi-0.0.4-py3-none-any.whl.metadata (20 kB)
# Collecting claudette
#   Downloading claudette-0.0.9-py3-none-any.whl.metadata (31 kB)
# Collecting colpali-engine<0.4.0,>=0.3.0 (from byaldi)
#   Downloading colpali_engine-0.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from byaldi) (0.4.1)
# Collecting mteb==1.6.35 (from byaldi)
#   Downloading mteb-1.6.35-py3-none-any.whl.metadata (23 kB)
# Collecting ninja (from byaldi)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Collecting pdf2image (from byaldi)
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: srsly in /usr/local/lib/python3.10/dist-packages (from byaldi) (2.4.8)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from byaldi) (2.4.1+cu121)
# Requirement already satisfied: transformers>=4.42.0 in /usr/local/lib/python3.10/dist-packages (from byaldi) (4.44.2)
# Collecting datasets>=2.2.0 (from mteb==1.6.35->byaldi)
#   Downloading datasets-3.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting jsonlines (from mteb==1.6.35->byaldi)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (1.26.4)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (1.13.1)
# Collecting sentence-transformers>=2.2.0 (from mteb==1.6.35->byaldi)
#   Downloading sentence_transformers-3.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (13.8.1)
# Collecting pytrec-eval-terrier>=0.5.6 (from mteb==1.6.35->byaldi)
#   Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (777 bytes)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (2.9.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (4.12.2)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (0.2.0)
# Requirement already satisfied: fastcore>=1.5.33 in /usr/local/lib/python3.10/dist-packages (from claudette) (1.7.8)
# Collecting anthropic (from claudette)
#   Downloading anthropic-0.34.2-py3-none-any.whl.metadata (18 kB)
# Collecting toolslm (from claudette)
#   Downloading toolslm-0.0.6-py3-none-any.whl.metadata (3.9 kB)
# Collecting gputil (from colpali-engine<0.4.0,>=0.3.0->byaldi)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting peft<0.12.0,>=0.11.0 (from colpali-engine<0.4.0,>=0.3.0->byaldi)
#   Downloading peft-0.11.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pillow<11.0.0,>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from colpali-engine<0.4.0,>=0.3.0->byaldi) (10.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore>=1.5.33->claudette) (24.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->byaldi) (0.24.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->byaldi) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->byaldi) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->byaldi) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->byaldi) (0.19.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from anthropic->claudette) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic->claudette) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from anthropic->claudette)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic->claudette)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from anthropic->claudette) (1.3.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from srsly->byaldi) (2.0.10)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from toolslm->claudette) (4.12.3)
# Collecting html2text (from toolslm->claudette)
#   Downloading html2text-2024.2.26.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting llms-txt (from toolslm->claudette)
#   Downloading llms_txt-0.0.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic->claudette) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic->claudette) (1.2.2)
# Collecting pyarrow>=15.0.0 (from datasets>=2.2.0->mteb==1.6.35->byaldi)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.2.0->mteb==1.6.35->byaldi)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (2.1.4)
# Collecting xxhash (from datasets>=2.2.0->mteb==1.6.35->byaldi)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets>=2.2.0->mteb==1.6.35->byaldi)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (3.10.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->anthropic->claudette) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->anthropic->claudette)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->anthropic->claudette)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft<0.12.0,>=0.11.0->colpali-engine<0.4.0,>=0.3.0->byaldi) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft<0.12.0,>=0.11.0->colpali-engine<0.4.0,>=0.3.0->byaldi) (0.34.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->mteb==1.6.35->byaldi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->mteb==1.6.35->byaldi) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (2.0.7)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (3.5.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->toolslm->claudette) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->byaldi) (2.1.5)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->mteb==1.6.35->byaldi) (24.2.0)
# Collecting nbdev (from llms-txt->toolslm->claudette)
#   Downloading nbdev-2.3.31-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mteb==1.6.35->byaldi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mteb==1.6.35->byaldi) (2.18.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->byaldi) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (4.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mteb==1.6.35->byaldi) (0.1.2)
# Collecting execnb>=0.1.4 (from nbdev->llms-txt->toolslm->claudette)
#   Downloading execnb-0.1.6-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.10/dist-packages (from nbdev->llms-txt->toolslm->claudette) (1.6.3)
# Collecting ghapi>=1.0.3 (from nbdev->llms-txt->toolslm->claudette)
#   Downloading ghapi-1.0.6-py3-none-any.whl.metadata (13 kB)
# Collecting watchdog (from nbdev->llms-txt->toolslm->claudette)
#   Downloading watchdog-5.0.2-py3-none-manylinux2014_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 1.4 MB/s eta 0:00:00
# Collecting asttokens (from nbdev->llms-txt->toolslm->claudette)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2024.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (7.34.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse->nbdev->llms-txt->toolslm->claudette) (0.44.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (71.0.4)
# Collecting jedi>=0.16 (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (3.0.47)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->execnb>=0.1.4->nbdev->llms-txt->toolslm->claudette) (0.2.13)
# Downloading Byaldi-0.0.4-py3-none-any.whl (20 kB)
# Downloading mteb-1.6.35-py3-none-any.whl (517 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.9/517.9 kB 14.8 MB/s eta 0:00:00
# Downloading claudette-0.0.9-py3-none-any.whl (21 kB)
# Downloading colpali_engine-0.3.0-py3-none-any.whl (27 kB)
# Downloading anthropic-0.34.2-py3-none-any.whl (891 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.9/891.9 kB 27.8 MB/s eta 0:00:00
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 13.0 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading toolslm-0.0.6-py3-none-any.whl (13 kB)
# Downloading datasets-3.0.0-py3-none-any.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 20.8 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.7 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 14.5 MB/s eta 0:00:00
# Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 13.8 MB/s eta 0:00:00
# Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 10.9 MB/s eta 0:00:00
# Downloading sentence_transformers-3.1.1-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 17.8 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading llms_txt-0.0.3-py3-none-any.whl (13 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.7 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 18.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.1 MB/s eta 0:00:00
# Downloading nbdev-2.3.31-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.4/67.4 kB 3.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.0 MB/s eta 0:00:00
# Downloading execnb-0.1.6-py3-none-any.whl (14 kB)
# Downloading ghapi-1.0.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 3.7 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading watchdog-5.0.2-py3-none-manylinux2014_x86_64.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 kB 7.2 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Building wheels for collected packages: gputil, html2text
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=54730ca5c4720cadd01968f7b7ed867dd086b5cca3d35076a9e97ae0aed87d0a
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
#   Building wheel for html2text (setup.py) ... done
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33111 sha256=939aa4e91a9985a77f3d01bc940238db839f25983c63774721afe53f0bab63a0
#   Stored in directory: /root/.cache/pip/wheels/f3/96/6d/a7eba8f80d31cbd188a2787b81514d82fc5ae6943c44777659
# Successfully built gputil html2text
# Installing collected packages: ninja, gputil, xxhash, watchdog, pytrec-eval-terrier, pyarrow, pdf2image, jsonlines, jiter, jedi, html2text, h11, dill, asttokens, multiprocess, httpcore, ghapi, httpx, execnb, nbdev, anthropic, sentence-transformers, peft, llms-txt, datasets, toolslm, mteb, colpali-engine, claudette, byaldi
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed anthropic-0.34.2 asttokens-2.4.1 byaldi-0.0.4 claudette-0.0.9 colpali-engine-0.3.0 datasets-3.0.0 dill-0.3.8 execnb-0.1.6 ghapi-1.0.6 gputil-1.4.0 h11-0.14.0 html2text-2024.2.26 httpcore-1.0.5 httpx-0.27.2 jedi-0.19.1 jiter-0.5.0 jsonlines-4.0.0 llms-txt-0.0.3 mteb-1.6.35 multiprocess-0.70.16 nbdev-2.3.31 ninja-1.11.1.1 pdf2image-1.17.0 peft-0.11.1 pyarrow-17.0.0 pytrec-eval-terrier-0.5.6 sentence-transformers-3.1.1 toolslm-0.0.6 watchdog-5.0.2 xxhash-3.5.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.5 [186 kB]
# Fetched 186 kB in 1s (212 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package poppler-utils.
# (Reading database ... 123599 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.5_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.5) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting openai
#   Downloading openai-1.47.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.47.0-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.6/375.6 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: openai
# Successfully installed openai-1.47.0

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git qwen-vl-utils flash-attn optimum auto-gptq bitsandbytes
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 33.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 60.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 105.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Building wheel for flash-attn (setup.py) ... done

# %%
from google.colab import userdata

# %%
import base64
import os
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')# to download the ColPali model
# os.environ["ANTHROPIC_API_KEY"] = userdata.get('ANTHROPIC_API_KEY')
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
from byaldi import RAGMultiModalModel
from claudette import *

# %%
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2", verbose=1)
# Out:
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# adapter_config.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/862M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/78.6M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/243k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.8M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/733 [00:00<?, ?B/s]

# %% [markdown]
# ### Download the "Attention is all you need" paper

# %%
# !wget https://arxiv.org/pdf/1706.03762
# !mkdir docs
# !mv 1706.03762 docs/attention.pdf
# Out:
# --2024-09-23 13:59:44--  https://arxiv.org/pdf/1706.03762
# Resolving arxiv.org (arxiv.org)... 151.101.131.42, 151.101.3.42, 151.101.195.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.131.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2215244 (2.1M) [application/pdf]
# Saving to: ‘1706.03762’
#
# 1706.03762          100%[===================>]   2.11M  --.-KB/s    in 0.05s
#
# 2024-09-23 13:59:44 (45.2 MB/s) - ‘1706.03762’ saved [2215244/2215244]

# %% [markdown]
# ### Indexing

# %%
RAG.index(
    input_path="./docs/attention.pdf",
    index_name="attention",
    store_collection_with_index=True, # set this to false if you don't want to store the base64 representation
    overwrite=True
)
# Out:
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Added page 1 of document 0 to index.
# Added page 2 of document 0 to index.
# Added page 3 of document 0 to index.
# Added page 4 of document 0 to index.
# Added page 5 of document 0 to index.
# Added page 6 of document 0 to index.
# Added page 7 of document 0 to index.
# Added page 8 of document 0 to index.
# Added page 9 of document 0 to index.
# Added page 10 of document 0 to index.
# Added page 11 of document 0 to index.
# Added page 12 of document 0 to index.
# Added page 13 of document 0 to index.
# Added page 14 of document 0 to index.
# Added page 15 of document 0 to index.
# Index exported to .byaldi/attention
# Index exported to .byaldi/attention
# {0: 'docs/attention.pdf'}

# %%
RAG.index
# Out:
# <bound method RAGMultiModalModel.index of <byaldi.RAGModel.RAGMultiModalModel object at 0x7adea808df30>>

# %% [markdown]
# ### Query time

# %%
query = "What's the BLEU score for the transformer base model?"

# %%
results = RAG.search(query, k=1)

# %%
print(type(results))
# Out:
# <class 'list'>

# %%
results
# Out:
# [{'doc_id': 0, 'page_num': 8, 'score': 19.875, 'metadata': {}, 'base64': '...'}]

# %%
# prompt: save the above result and load it again after session restart

import pickle

# Save the results to a file
with open('results.pkl', 'wb') as f:
  pickle.dump(results, f)

# %% [markdown]
# ### Actual image data

# %%
image_bytes = base64.b64decode(results[0].base64)

# %%
filename = 'image.jpg'  # I assume you have a JPG file
with open(filename, 'wb') as f:
  f.write(image_bytes)

# %%
from IPython.display import Image

display(Image(filename))

# %% [markdown]
# ### Send the image to a vision language model (claude)

# %%
# we weill use https://claudette.answer.ai/ for interacting with claude

# %%
chat = Chat(models[1])
# models is a claudette helper that contains the list of models available on your account, as of 2024-09-06, [1] is Claude Sonnet 3.5:
models
# Out:
# ('claude-3-opus-20240229',
#  'claude-3-5-sonnet-20240620',
#  'claude-3-haiku-20240307')

# %%
from openai import OpenAI
import requests
client = OpenAI()
api_key = userdata.get('OPENAI_API_KEY')
headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
}


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "image.jpg"

# Getting the base64 string
base64_image = encode_image(image_path)

payload = {
  "model": "gpt-4o-mini",
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": f'{query}'
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 300
}

response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload).json()

print(response)

print(response['choices'][0]['message']['content'])
# Out:
# {'id': 'chatcmpl-AA5DvWGn10QxKyVZFrRR0iQolOpb4', 'object': 'chat.completion', 'created': 1726966723, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'In the document you provided, the BLEU scores for the Transformer base model are as follows:\n\n- For English-to-German (EN-DE): **27.3**\n- For English-to-French (EN-FR): **38.1**\n\nThese scores indicate the performance of the Transformer base model in machine translation tasks.', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 25519, 'completion_tokens': 65, 'total_tokens': 25584, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_e9627b5346'}
# In the document you provided, the BLEU scores for the Transformer base model are as follows:
#
# - For English-to-German (EN-DE): **27.3**
# - For English-to-French (EN-FR): **38.1**
#
# These scores indicate the performance of the Transformer base model in machine translation tasks.

# %%
#if you want to use antropic

# chat([image_bytes, query])

# %% [markdown]
# # Time to test local models

# %%
# !pip uninstall transformers -y

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git qwen-vl-utils flash-attn optimum auto-gptq bitsandbytes

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info
import torch

model = Qwen2VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2-VL-2B-Instruct",
    trust_remote_code=True,
    torch_dtype=torch.bfloat16).cuda().eval()
# Out:
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# model.safetensors.index.json:   0%|          | 0.00/56.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]

# %%
processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-2B-Instruct", trust_remote_code=True)
# Out:
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]

# %%
from pdf2image import convert_from_path

images = convert_from_path("./docs/attention.pdf")

# %%
images[7]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200>

# %%
# After session restart, load the results from the file
import pickle
with open('results.pkl', 'rb') as f:
  results = pickle.load(f)

print(results)
# Out:
# [{'doc_id': 0, 'page_num': 8, 'score': 19.5, 'metadata': {}, 'base64': '...'}]

# %%
image_index = results[0]["page_num"] - 1
image_index
# Out:
# 7

# %%
query = "What's the BLEU score for the transformer base model?"

# %%
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": images[image_index],
            },
            {"type": "text", "text": query},
        ],
    }
]

# %%
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)

# %%
text
# Out:
# "<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n<|im_start|>user\n<|vision_start|><|image_pad|><|vision_end|>What's the BLEU score for the transformer base model?<|im_end|>\n<|im_start|>assistant\n"

# %%
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")

# %%
inputs
# Out:
# {'input_ids': tensor([[151644,   8948,    198,  ..., 151644,  77091,    198]],
#        device='cuda:0'), 'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]], device='cuda:0'), 'pixel_values': tensor([[1.9303, 1.9303, 1.9303,  ..., 2.1459, 2.1459, 2.1459],
#         [1.9303, 1.9303, 1.9303,  ..., 2.1459, 2.1459, 2.1459],
#         [1.9303, 1.9303, 1.9303,  ..., 2.1459, 2.1459, 2.1459],
#         ...,
#         [1.9303, 1.9303, 1.9303,  ..., 2.1459, 2.1459, 2.1459],
#         [1.9303, 1.9303, 1.9303,  ..., 2.1459, 2.1459, 2.1459],
#         [1.9303, 1.9303, 1.9303,  ..., 2.1459, 2.1459, 2.1459]],
#        device='cuda:0'), 'image_grid_thw': tensor([[  1, 158, 122]], device='cuda:0')}

# %%
generated_ids = model.generate(**inputs, max_new_tokens=50)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)

# %%
print(output_text)
# Out:
# ['The BLEU score for the transformer base model is 27.3.']
